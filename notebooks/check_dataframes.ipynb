# %%
import pandas as pd

# %%
df = pd.read_parquet("../input/train_image_data_0.parquet")

# %%
# !ls
# Out:
# check_dataframes.ipynb

# %%
df.head()
# Out:
#   image_id    0    1    2    3    4    5    6    7    8  ...  32322  32323  \
# 0  Train_0  254  253  252  253  251  252  253  251  251  ...    253    253
# 1  Train_1  251  244  238  245  248  246  246  247  251  ...    255    255
# 2  Train_2  251  250  249  250  249  245  247  252  252  ...    254    253
# 3  Train_3  247  247  249  253  253  252  251  251  250  ...    254    254
# 4  Train_4  249  248  246  246  248  244  242  242  229  ...    255    255
#
#    32324  32325  32326  32327  32328  32329  32330  32331
# 0    253    253    253    253    253    253    253    251
# 1    255    255    255    255    255    255    255    254
# 2    252    252    253    253    253    253    251    249
# 3    254    254    254    253    253    252    251    252
# 4    255    255    255    255    255    255    255    255
#
# [5 rows x 32333 columns]

# %%
import sys
sys.path.append("../src/")
import torch
import matplotlib.pyplot as plt
from dataset import BengaliDatasetTrain
# %matplotlib inline     # shows the images
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-fe699bdc29f1> in <module>
#       3 import torch
#       4 import matplotlib.pyplot as plt
# ----> 5 from dataset import BengaliDatasetTrain
#       6 # %matplotlib inline     # shows the images
#
# ~\Desktop\Studies\PyCharm_Projects\kaggle_competitions\KAGGLE_Bengali.AI_handwritten_grapheme_classification_using_PyTorch\src\dataset.py in <module>
# ----> 1 import albumentations           # augmentation library
#       2 import joblib
#       3 import pandas as pd
#       4 import numpy as np
#       5 from PIL import Image
#
# ~\anaconda3\lib\site-packages\albumentations\__init__.py in <module>
#       3 __version__ = "0.4.5"
#       4
# ----> 5 from .core.composition import *
#       6 from .core.transforms_interface import *
#       7 from .core.serialization import *
#
# ~\anaconda3\lib\site-packages\albumentations\core\composition.py in <module>
#       9 from albumentations.core.serialization import SerializableMeta
#      10 from albumentations.core.six import add_metaclass
# ---> 11 from albumentations.core.transforms_interface import DualTransform
#      12 from albumentations.core.utils import format_args, Params
#      13 from albumentations.augmentations.bbox_utils import BboxProcessor
#
# ~\anaconda3\lib\site-packages\albumentations\core\transforms_interface.py in <module>
#       4 from warnings import warn
#       5
# ----> 6 import cv2
#       7 from copy import deepcopy
#       8
#
# ImportError: DLL load failed: The specified module could not be found.

# %%
dataset = BengaliDatasetTrain(folds=[0,1], img_height=137, img_width=236,
                             mean=(0.485, 0.456, 0.406),
                             std=(0.229, 0.224, 0.225))
